# %% [markdown]
# # Page Curve Entanglement Dynamics in Open Two-Level Quantum Systems: Lindbland Master Equation
# Author: Anastasiya Khromova (anastasiya.khromova17@gmail.com), 2025

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# ## Introduction
#
# ### Unitary and Non-Unitary Isometric Time Evolution
#
# **Unitary** time evolution is a fundamental concept in quantum mechanics. It means that the state of a quantum system evolves over time according to a **unitary operator**. This operator is reversible and preserves the total probability (i.e., the sum of the probabilities of all possible outcomes remains 1). It is a way to describe how a **closed** quantum system changes over time without losing information.
#
# **Non-unitary isometric time evolution**, on the other hand, is a bit more complex. It's used when dealing with **open quantum systems**, which can interact with their environment. In this case, the evolution of the system is described by an isometric but non-unitary operator. This means that while the transformation still preserves the norm (i.e., the total probability remains 1), it is not necessarily reversible. This reflects the fact that information can be lost to the environment in an **open system**. This **non-reversibility reflects** the fact that information can be lost to the environment in an **open system**.
#
# A **quantum open system** refers to a quantum system that interacts with an external environment (often called a "bath" or "reservoir"). Because of this interaction, the system is not isolated, and its dynamics are influenced by the environment. This leads to phenomena such as decoherence (loss of quantum coherence due to interaction with the environment), dissipation (loss of energy from the system to the environment) and noise (random fluctuations introduced by the environment). In open quantum systems, the evolution of the system is typically **non-unitary** because information (e.g., quantum states or energy) is lost to the environment. This is described mathematically using tools like the e.g. master equation like **Lindblad equation**. **Non-unitary isometric evolution** refers to a specific type of mathematical description used in quantum mechanics. The combined system (system + environment) evolves **unitarily**, but the evolution of the system alone is non-unitary because it is "traced over" the environment (i.e., the environment is treated as an external degrees of freedom that is not observed).
#
# In **open quantum systems**, the evolution is typically **non-unitary** because the system can exchange information and energy with its environment. This is in contrast to **closed systems**, where the evolution is **unitary** and no information is lost. When we consider the **combined system** of the quantum system and its environment, the evolution is unitary. However, when we focus only on the system and "trace over" the environment (i.e., average over all possible states of the environment), the resulting evolution for the system alone is **non-unitary**. This reflects the fact that we're not keeping track of the environment's degrees of freedom, which can carry away information from the system.
#
# The **Page curve** is a concept from quantum information theory that describes how the **entanglement entropy** of a subsystem evolves over time when a **pure state** is subjected to **unitary evolution**. In simpler terms, it shows how the amount of information shared between two parts of a system changes as the system evolves. The curve is named after Don Page, who first described it in the context of **black hole evaporation**. The **Page curve** typically has a characteristic shape: it starts at zero, rises to a maximum value, and then decreases back to zero. This behavior is thought to be a consequence of the subsystem becoming increasingly **entangled** with the rest of the system, and then becoming less entangled as the system approaches a pure state again.
#
# The **Page curve**, which describes the entropy dynamics of a **black hole**, provides a framework for understanding how information is preserved during **black hole evaporation**. According to the Page curve, the entropy of a black hole initially increases as it emits Hawking radiation, reaching a maximum value at the Page time. After the **Page time**, the entropy starts to decrease: the emitted radiation carries the information away. This decrease in entropy suggests that the evaporation process is **unitary** and that information is not lost, but rather encoded in the **entanglement** between the black hole and the radiation.
#
# To check if a time evolution is non-unitary but isometric, you need to verify two properties of the evolution operator:
#
# - **Isometry**: An operator U is isometric if it preserves the norm of the state vectors:
#
# <div align="center">
#     <img src="Images/equation_isometry.png">
# </div>
#
# for all state vectors |ψ⟩. This means that the total probability is conserved under the evolution.If the norm is preserved for all state vectors, the operator is **isometric**. If the norm of the state vectors remains constant under the evolution, it implies that the **inner product** is preserved.
#
# - **Non-unitarity**: An operator U is non-unitary if it does not satisfy the condition:
# <div align="center">
#     <img src="Images/equation_unitarity.png">
# </div>
# where U† is the adjoint (conjugate transpose) of U, and I is the identity operator. In other words, the operator is not reversible. Compute the products U†U and UU†. If either product is not equal to the identity operator, then the operator is non-unitary.
#
# - **Non-Unitary Isometric Evolution**: If your checks confirm that the system's entropy increases and purity decreases over time, while the trace of the density matrix remains constant, this suggests non-unitary isometric evolution. The system alone is losing information to the environment, consistent with **non-unitary dynamics**.
#
#    - The **von Neumann entropy** measures the mixedness of a quantum state:
#      <div align="center">
#          <img src="Images/equation_vonNeumann_entrop.png">
#      </div>
#      An increase in entropy indicates loss of information to the environment, suggesting non-unitary evolution.
#
#    - **Purity**, defined as:
#      <div align="center">
#          <img src="Images/equation_purity.png">
#      </div>
#      where ρ is the density matrix of the quantum system, and Tr represents the trace operation. The purity is calculated by taking the trace of the square of the density matrix and it indicates how mixed a state is. A decrease in          purity over time suggests non-unitary evolution.
#
#    - The **trace** of the density matrix should remain constant (equal to 1) to ensure the evolution is trace-preserving, a necessary condition for **isometric evolution**.
#
# - The observation of the **Page curve** indicates that the combined system (system + environment) evolves **unitarily**, preserving information overall.
#
#
# >Modeling **black hole evaporation** using a **two-level quantum system** is a simplified approach that can provide some insights into the process, but it may not capture all the complexities of an actual black hole. The fact that we still obtained the **Page curve** in the simulation is interesting and suggests that the model can reproduce some key features of black hole evaporation. In the simulation, the two-level system interacts with an environment, leading to **dissipation** and **decoherence**. This interaction causes the system to lose information to the environment, which is analogous to the black hole losing information to the emitted radiation during evaporation. The Page curve obtained in the simulation showed that the entropy of the system initially increases, reaches a maximum, and then decreases, indicating that information is not lost but rather becomes encoded in the **entanglement** between the system and the environment. This behavior is similar to what is expected in black hole evaporation, where the entropy of the emitted radiation follows the Page curve, suggesting that information is preserved in the entanglement between the black hole and the radiation. In both cases, the information is not lost but becomes encoded in the correlations between the system (black hole or two-level system) and the environment (radiation or external degrees of freedom).
#
# However, there are some limitations to using a two-level system to model black hole evaporation. A real black hole is a much more complex system with a large number of degrees of freedom, and its evaporation process involves quantum gravity effects that are not captured by a simple two-level system. Additionally, the two-level system does not include the effects of spacetime curvature or the formation of a horizon, which are crucial aspects of black hole physics.
#
# Despite these limitations, the simulation demonstrates that even a simplified model can exhibit the Page curve behavior, suggesting that the key features of information preservation during black hole evaporation can be captured by a system that loses information to an environment through dissipation and decoherence. This supports the idea that black hole evaporation is a unitary process and that information is not lost but rather encoded in the entanglement between the black hole and the emitted radiation.
#
# If you consider the hypothesis that **entropy** (S) drives **gravity** (the von Neuman entropy drives the gravity), the hypothesis that has been explored in various contexts, most notably in the context of the holographic principle and the AdS/CFT correspondence. In these frameworks, gravity is thought to be an emergent phenomenon that arises from the entanglement entropy of the underlying quantum degrees of freedom. The von Neumann entropy of the two-level system, which models the black hole, changes over time due to its interaction with the environment. This change in entropy could be viewed as driving the gravitational dynamics of the black hole. As the black hole evaporates and loses information to the environment (in our case, the two-level system losing information to the external degrees of freedom), the von Neumann entropy follows the Page curve. This suggests that the gravitational dynamics of the black hole are closely related to the entanglement entropy between the black hole and the emitted radiation. The fact that the von Neumann entropy decreases in the latter stages of the Page curve implies that the gravitational effects become weaker as the black hole evaporates and information is transferred to the radiation.
#
# We attempt a simple toy-model simulation for exercising black hole evaporation by a two-level system with the help of **QuTip** (Quantum Toolbox in Python). Our goal is to obtain a **Page curve** using the simple two-level atomic system.
#
#
# ### From Schrödinger to von Neumann equation
#
#
# The time-dependent **Schrödinger equation** describes the evolution of a pure quantum state over time of a **closed quantum system**. It is given by:
#
# <div align="center">
#     <img src="Images/equation_schroedinger_eq.png">
# </div>
#
# where **H** is the Hamiltonian operator describing the closed system, and **∣ψ(t)⟩** is the system’s quantum state at time t.
# The general solution to this equation for time-independent **H** is given by:
# <div align="center">
#     <img src="Images/equation_schroedinger_solution.png">
# </div>
#
# where exp(–iHt/ℏ) is the time-evolution operator **U(t)**:
#
#
# <div align="center">
#     <img src="Images/equation_schroedinger_evolution.png">
# </div>
#
#
# As **H** is a **Hermitian** operator, the operator U=exp(−iHt) is **unitary**. This time-evolution operator is always an **isometry**, as it preserves the inner product between states. This means that for any two states ∣ψ⟩ and ∣ϕ⟩ in the Hilbert space, we have:
#
# <div align="center">
#     <img src="Images/equation_isometry_product.png">
# </div>
#
# Here, U(t)† represents the adjoint (conjugate transpose) of the unitary operator U(t). Since U(t) is **unitary**, its adjoint is equal to its inverse, i.e., U(t)^†=U(t)⁻¹. The equation above implies that the inner product between the states ∣ψ⟩ and ∣ϕ⟩ remains unchanged when the states evolve under the unitary operator U(t), ensuring that the probabilities and relationships between states are maintained throughout the evolution of the quantum system. This property is crucial in quantum mechanics, as it guarantees that the time-evolution of a quantum system is reversible and preserves the overall structure of the **Hilbert space**.
#
# - If H is Hermitian, then a unitary operator satisfies:
#
# <div align="center">
#     <img src="Images/equation_unitary_operation_prop.png">
# </div>
#
#
# <div align="center">
#     <img src="Images/equation_unitary_operation_prop2.png">
# </div>
#
# - If H is not Hermitian, then U(t) is still an isometry but not necessarily unitary.
#
# When studying the dynamics of quantum systems using the density operator representation, Schrödinger’s equation becomes:
# <div align="center">
#     <img src="Images/equation_vonNeumann.png">
# </div>
# known as the **von Neumann equation**, where H is the Hamiltonian of the **closed system** (which can be time-dependent) and the brackets denote a commutator. It describes the time evolution of a quantum system's density matrix ρ(t). In Dirac notation, the density matrix representation of a pure quantum state ∣ψ⟩ is given by:
# <div align="center">
#     <img src="Images/equation_density_matrix.png">
# </div>
#
# Here, ∣ψ⟩ is the wave function (or ket) representing the quantum state, and ⟨ψ∣ is the corresponding bra. The density matrix ρ is a **Hermitian operator** that fully describes the quantum state.
#
#
# The dynamics of an **open quantum system** arise from an interaction between the system of interest (the “main” system) and an environment, which together form a **closed quantum system**. There are different methods to describe open quantum systems.
#
#
# ### The Lindbland Master Equation
# The Lindblad equation (master equation in Lindblad form, quantum Liouvillian, or Lindbladian) is a popular Markovian quantum master equation that is widely used in quantum optics, quantum information, and open quantum systems. It ensures the positivity of the density matrix, providing more physically meaningful results. It is typically used for systems with weak system-bath coupling and short-time dynamics. Nevertheless, it is still an approximation to the full quantum dynamics and may not capture all the relevant physics.
#
# The Lindblad master equation (also known as the Gorini-Kossakowski-Sudarshan-Lindblad GKSL master equation) for the system’s density matrix ρ can be written as:
# <div align="center">
#     <img src="Images/equation_Lindbland1.png">
# </div>
# where H is the system Hamiltonian (the coherent part of the dynamics), {Lₖ} are the Lindblad operators (jump operators) that must not be Hermitian and representing the coupling of the system to its environment — some non-unitary processes like relaxation or decoherence that occur at some rates {γₖ} (damping rates), ρ is the density matrix and:
# <div align="center">
#     <img src="Images/equation_Lindbland_anticom.png">
# </div>
# is an anticommutator. If all γᵢ=0, one recovers the von Neumann equation describing unitary dynamics, which is the quantum analog of the classical Liouville equation.
#
# ###  References
#
# [1] Dynamics and Time-Evolution, https://qutip.readthedocs.io/en/qutip-5.1.x/apidoc/solver.html#qutip.solver.mesolve.mesolve
# [2] Lindblad Master Equation Solver, https://qutip.readthedocs.io/en/qutip-5.1.x/guide/dynamics/dynamics-master.html
#
# </font>

# %% [markdown]
# ## Imports
# <font face="Arial" size="4" color="black">
#
# We import:
# - The NumPy library, which is a powerful library for numerical computing in Python. By using the alias np, you can access NumPy functions and classes using the shorter np. prefix instead of typing out numpy. each time.
# - The Matplotlib library, specifically the pyplot module. Matplotlib is a popular plotting library in Python that allows you to create a wide range of visualizations. By using the alias plt, you can access the plotting functions and classes using the shorter plt. prefix.
# - The QuTiP library. QuTiP is a Python library specifically designed for simulating and analyzing quantum systems. The * symbol is a wildcard that imports everything from the library, allowing you to use its functions and classes directly without needing to prefix them with qutip.
#
# </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import * #Qutip is a Python library for simulating quantum systems.

# %% [markdown]
# ## Two-level system evolution
#
# <font face="Arial" size="4" color="black">
#
# Consider a simplified scenario involving a two-level system (i.e., a spin-1/2 particle) interacting with a bath (representing the Hawking radiation). This example will help us understand how entanglement with the bath increases the system’s entropy.
#
# The total Hamiltonian H of the system is made up of two parts:
#
# <div align="center">
#     <img src="Images/equation_hamiltonian.png">
# </div>
#
# Here, H₀ is the bare atomic Hamiltonian without any radiation acting on it, and
#
# <div align="center">
#     <img src="Images/equation_hamiltonian_int.png">
# </div>
# describes the interaction with a time-dependent Electromagnetic (EM) field.
#
# We have:
#
# <div align="center">
#     <img src="Images/equation_atomic_hamil.png">
# </div>
#
# </font>
# where
#
# <div align="center">
#     <img src="Images/equation_Pauliz.png">
# </div>
#
# is a Pauli matrix, and ℏω₀ is the energy difference of the atomic levels. In terms of the energy levels, E₀ = ℏω₀ and E₁=ℏω₁:
#
# <div align="center">
#     <img src="Images/equation_hamiltonian_atom_braket.png">
# </div>
#
# This is the coherent part of the atom’s evolution.
#
# The eigenvalues of this Hamiltonian give the energies of the two levels. By defining the transition frequency as ω₀=ω₂–ω₁, we can shift the zero point energy and rewrite the Hamiltonian as:
#
# <div align="center">
#     <img src="Images/equation_atomH0.png">
# </div>
#
#
# The energy difference between the states remains the same (ℏω₀); we have just defined the energy of the lowest state to be zero:
#
# <div align="center">
#     <img src="Images/equation_atomH0_2.png">
# </div>
#
# with E=E₁. Using the laser or radio frequency (RF) electromagnetic fields, we can include a driving force that coherently switches between both states (Rabi oscillations with Rabi frequency Ω). A laser field with frequency ω. Since we are considering near-resonant excitation, we have ω ≈ ω₀. We can quantify the difference between the laser frequency and the resonant frequency of the transition as ∆=ω–ω₀, known as the detuning. In the ‘rotating wave approximation’, the interaction Hamiltonian will have the form:
#
# <div align="center">
#     <img src="Images/equation_hamiltonian_inter.png">
# </div>
#
# To eliminate the explicit time dependence in the Hamiltonian, we can transform a frame into a rotating one.
#
# The total Hamiltonian would be then:
#
# <div align="center">
#     <img src="Images/equation_hamiltonian_total.png">
# </div>
#
# he term **(|0⟩⟨1| + |1⟩⟨0|)** in the given Hamiltonian represents the Pauli matrix
#
# <div align="center">
#     <img src="Images/equation_sigmax.png">
# </div>
#
# Let’s code the dynamics using Python and the **QuTIP library**, and visualize the result. It follows exactly the physics described above.
#
# </font>

# %%
# Define parameters
Omega =1  # Rabi frequency represents the strength of the interaction between the two states.
hbar=1
sx = sigmax() # Pauli X matrix
Delta=0.1 #Delta=w-w0 where w is the laser frequency and w0 is  the atomic transition frequency

# Define basis states
g = basis(2, 0)  # Ground state |g>, the first argument is the dimension of the Hilbert space (2 for a two-level system), and the second argument is the index of the state.
e = basis(2, 1)  # Excited state |e>

H_0=hbar*(-2*Delta)*e * e.dag()
print(H_0)
H_I=hbar*Omega/2*sx
print(H_I)
H_total=H_0+H_I
print(H_total)

# Initial state (pure excited state)
psi0 = e # The initial state psi0 is set to the excited state e.

ee = e * e.dag() #Projection operator |e><e|, representing the population in the excited state
gg = g * g.dag() # Projection operator |g><g|, representing the population in the ground state
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=CSR, isherm=True
# Qobj data =
# [[ 0.   0. ]
#  [ 0.  -0.2]]
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=CSR, isherm=True
# Qobj data =
# [[0.  0.5]
#  [0.5 0. ]]
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=CSR, isherm=True
# Qobj data =
# [[ 0.   0.5]
#  [ 0.5 -0.2]]

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# Now we will solve the Scrödinger Equation. For the Schrödinger equation for only the **coherent dynamics** of the state vector |ψ⟩ as defined earlier, we would find that the solutions are oscillatory - **Rabi oscillations**.
#
#
# Let's generate tlist array that will be used to specify the time points at which the system's evolution will be calculated.
#
#  - tlist = np.linspace(0, 20, 2000): This line creates an array of time points using the numpy.linspace() function. It generates 2000 evenly spaced time points from 0 to 20 (inclusive).
#
# The mesolve() function returns an object (result) that contains the results of the time evolution, including the state vectors or expectation values at each time point specified in tlist. This line uses the mesolve() function from QuTiP to solve the Schrödinger equation for the given quantum system.
#
#  - result = mesolve(H_total, psi0, tlist, [], [ee, gg]):
#
#    - The mesolve() function takes several arguments:
#         H_total is the total Hamiltonian of the system, which describes the system's dynamics.
#         psi0 is the initial state of the system, represented as a quantum state vector.
#         tlist is the array of time points at which the system's evolution will be calculated (obtained from the previous line).
#         [] is an empty list representing any collapse operators (not used in this case).
#         [ee, gg] is a list of operators or state vectors to be evaluated at each time point. In this case, ee and gg are the operators or state vectors of interest.
#
# </font>

# %%
tlist = np.linspace(0, 100, 2000)
result = mesolve(H_total, psi0, tlist, [], [ee, gg])

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# Then we plot the result.
# </font>

# %%
# Plot expectation values. The code plots the expectation values of the projection operator sz (population in the excited state) and the complement of sz (population in the ground state) over time.
plt.figure()
plt.plot(tlist, result.expect[0], color='red', label=r'$\langle e | e \rangle$ (Population in excited state)')
plt.plot(tlist, 1-result.expect[0], color='blue', label=r'$\langle g | g \rangle$ (Population in ground state)')
plt.xlim(0, 20)  # Set the x-axis limit to 5
plt.ylim(0, 1)  # Set the y-axis limit to start from 0
plt.xlabel("Time")
plt.ylabel("Population")
plt.legend()
plt.savefig('two-level system without damping.png', dpi=300)  # Save the plot as a PNG image
plt.show()

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# ## The Lindbland Equation
# The **Hamiltonian** generates **coherent dynamics**. The **Lindblad operators** generate **incoherent** transitions in the space of states. Unlike the **Hamiltonian**, they do not need to be **Hermitian**. A decay transition from some excited state |1⟩ to some ground state |0⟩ is mediated by the Lindblad operator:
#
# <div align="center">
#     <img src="Images/equation_Lindbland_oper.png">
# </div>
#
# Let’s now set the **detuning** Δ=0 in order to be at perfect resonance, and we also add **spontaneous emission** with the rate γ=0.1.
# </font>

# %%
Gamma = 0.1  # Gamma is the coupling between the atom and the vacuum.
#s_low=sigmam()
s_low=g * e.dag()
#A single jump operator 
L1=np.sqrt(Gamma)*s_low
result = mesolve(H_total, psi0, tlist, L1, [ee, gg])

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# And then we plot.
# </font>

# %%
# Plot expectation values. The code plots the expectation values of the projection operator sz (population in the excited state) and the complement of sz (population in the ground state) over time.
plt.figure()
plt.plot(tlist, result.expect[0], color='red', label=r'$\langle e | e \rangle$ (Population in excited state)')
plt.plot(tlist, 1-result.expect[0], color='blue', label=r'$\langle g | g \rangle$ (Population in ground state)')
plt.xlim(0, 20)  # Set the x-axis limit to 5
plt.ylim(0, 1)  # Set the y-axis limit to start from 0
plt.xlabel("Time")
plt.ylabel("Poplulation")
plt.savefig('two-level system with damping.png', dpi=300)  # Save the plot as a PNG image
plt.legend()
plt.show()

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# In the next step, let’s add **dephasing** to the **relaxation**.
# </font>

# %%
#Dephasing rate
gamma_phi = 0.1
# Jump operator for dephasing
sz = sigmaz()
L2 = np.sqrt(gamma_phi) * sz

result = mesolve(H_total, psi0, tlist, [L1, L2], [ee, gg])

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# And then we plot.
# </font>

# %%
plt.figure()
plt.plot(tlist, result.expect[0], color='red', label=r'$\langle e | e \rangle$ (Population in excited state)')
plt.plot(tlist, 1-result.expect[0], color='blue', label=r'$\langle g | g \rangle$ (Population in ground state)')
plt.xlim(0, 20)  # Set the x-axis limit to 5
plt.ylim(0, 1)  # Set the y-axis limit to start from 0
plt.xlabel("Time")
plt.ylabel("Population")
#plt.savefig('two-level system with damping dephasing.png', dpi=300)  # Save the plot as a PNG image
plt.legend()
plt.show()

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# Let's calculate the **von Neumann entropy** and plot it. Let’s plot first the entropy when the **Rabi frequency** Ω=1 as in an example above. The Rabi frequency represents the strength of the interaction between the two states due to the i.e. laser field. The von Neumann entropy is a measure of the **entanglement** between the system and its environment.
#
# If you don’t use the incoherent part in the Lindbland equation in QuTip, you will have the quantum state state=result.states in the result output. Including the incoherent Linbland operators, **result= mesolve(H_total, psi0, tlist, [L1, L2], [ee, gg], options=options)**, will return you the density matrices. If we were to solve the **Schrödinger equation** for the **coherent dynamics** of the state vector |ψ⟩ as defined earlier, we would find that the solutions are oscillatory (Rabi oscillations). In real atomic systems with **incoherent processes**, such as decay between the levels, it is not possible to consider the state vector alone. To include these incoherent processes, we need the **density operator** ρ, and we then study its evolution instead of the state vector’s evolution.
# </font>

# %%
# Set the options to store states
options = Options(store_states=True)
result= mesolve(H_total, psi0, tlist, [L1, L2], [ee, gg], options=options)

# Get the density matrices at different times
density_matrices=result.states
print("Initial density_matrix:")
print(density_matrices[0])
print("Final density_matrix:")
print(density_matrices[-1])

# Calculate the von Neumann entropy for each density matrix
entropies = [entropy_vn(rho, 2) for rho in density_matrices]

# Print the initial and final von Neumann entropies
print("Initial von Neumann entropy:", entropies[0])
print("Final von Neumann entropy:", entropies[-1])

# Plot the von Neumann entropy over time
plt.plot(tlist, entropies)
plt.xlabel("Time")
plt.ylabel("von Neumann Entropy")
plt.title("von Neumann Entropy vs Time")
plt.savefig('two-level system von Neumann entropy coherent.png', dpi=300)  # Save the plot as a PNG image
plt.show()
# Out:
# Initial density_matrix:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0. 0.]
#  [0. 1.]]
# Final density_matrix:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0.5196925 +0.j         0.03842461+0.04803074j]
#  [0.03842461-0.04803074j 0.4803075 +0.j        ]]
# Initial von Neumann entropy: 5.647277761308516e-16
# Final von Neumann entropy: 0.9879307757005888

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# The **initial state** is a pure excited state, and the system evolves under the given **Hamiltonian**. Therefore, the initial **von Neumann entropy** is zero, as expected, — we have maximum knowledge about the quantum state. As the system evolves and interacts with the environment, it may become **entangled** with the environment, leading to a **mixed state**. In this case, the **von Neumann entropy** can take non-zero values, and plotting its evolution over time can provide insights into the system’s dynamics and its entanglement with the environment. The entropy evolution over time, considering the presence of dissipation and dephasing in the system, and the coherent dynamics of the system with the Rabi frequency Ω=1, as it is shown in the figure above, we don’t observe the **Page curve**.
# </font>

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# Set the **Rabi frequency** Ω=0, and you will stay only with the **incoherent dynamics**. The resulting plot (figure below) shows an exponential decay of the excited state population and a corresponding increase in the ground state population, as expected for pure incoherent dynamics.
# </font>

# %%
# Define parameters
Omega = 0  # Rabi frequency represents the strength of the interaction between the two states.
hbar=1
sx = sigmax() # Pauli X matrix
Delta=0.1 #Delta=w-w0 where w is the laser frequency and w0 is  the atomic transition frequency

# Define basis states
g = basis(2, 0)  # Ground state |g>, the first argument is the dimension of the Hilbert space (2 for a two-level system), and the second argument is the index of the state.
e = basis(2, 1)  # Excited state |e>

H_0=hbar*(-2*Delta)*e * e.dag()
H_I=hbar*Omega/2*sx
H_total=H_0+H_I

# Initial state (pure excited state)
psi0 = e # The initial state psi0 is set to the excited state e.

ee = e * e.dag() #Projection operator |e><e|, representing the population in the excited state
gg = g * g.dag() # Projection operator |g><g|, representing the population in the ground state

# %%
# Define Pauli matrices
sz = e * e.dag()  # Projection operator |e><e|, representing the population in the excited state
sx = sigmax()     # Pauli X operator,  which is a 2x2 matrix representing the spin-1/2 particle in the x-direction
s_low=g * e.dag()
#A single jump operator 
L1=np.sqrt(Gamma)*s_low

#Dephasing rate
gamma_phi = 0.1
# Jump operator for dephasing
sz = sigmaz()
L2 = np.sqrt(gamma_phi) * sz

# %%
# Time evolution
tlist = np.linspace(0, 100, 2000)
result = mesolve(H_total, psi0, tlist, [L1, L2], [ee, gg])

# Plot expectation values. The code plots the expectation values of the projection operator sz (population in the excited state) and the complement of sz (population in the ground state) over time.
plt.figure()
plt.plot(tlist, result.expect[0], color='red', label=r'$\langle e | e \rangle$ (Population in excited state)')
plt.plot(tlist, 1-result.expect[0], color='blue', label=r'$\langle g | g \rangle$ (Population in ground state)')
plt.xlabel("Time")
plt.ylabel("Expectation values")
plt.legend()
#plt.savefig('two-level system incoherent damping dephasing.png', dpi=300)  # Save the plot as a PNG image
plt.show()

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# Let's now calculate the **von Neumann entropy** and plot it. When the Rabi frequensy is Ω=0, we would have only the **incoherent part**, and the Page curve immerges.
# </font>

# %%
# Set the options to store states
options = Options(store_states=True)
result= mesolve(H_total, psi0, tlist, [L1, L2], [ee, gg], options=options)

# Get the density matrices at different times
density_matrices=result.states
print("Initial density_matrix:")
print(density_matrices[0])
print("Final density_matrix:")
print(density_matrices[-1])

# Calculate the von Neumann entropy for each density matrix
entropies = [entropy_vn(rho, 2) for rho in density_matrices]

# Print the initial and final von Neumann entropies
print("Initial von Neumann entropy:", entropies[0])
print("Final von Neumann entropy:", entropies[-1])

# Plot the von Neumann entropy over time
plt.plot(tlist, entropies)
plt.xlabel("Time")
plt.ylabel("von Neumann Entropy")
plt.title("von Neumann Entropy vs Time")
#plt.savefig('two-level system incoherent damping dephasing von Neumann entropy.png', dpi=300)  # Save the plot as a PNG image
plt.show()
# Out:
# Initial density_matrix:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0. 0.]
#  [0. 1.]]
# Final density_matrix:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[9.99954605e-01 0.00000000e+00]
#  [0.00000000e+00 4.53949356e-05]]
# Initial von Neumann entropy: 5.647277761308516e-16
# Final von Neumann entropy: 0.0007204072519833418

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# Now we should proove that we have a **non-unitary isometic evolution**.
# </font>

# %%
# Calculate purity using the purity() method
purity = [state.purity() for state in density_matrices]

# Calculate trace (should always be 1 for valid density matrices)
trace = [rho.tr() for rho in density_matrices]

# Theoretical entropy of a maximally mixed state
entropy_max = entropy_vn((0.5 * g * g.dag() + 0.5 * e * e.dag()), 2)# This line calculates the theoretical maximum von Neumann entropy for a maximally mixed state of a two-level system.
#The maximally mixed state is represented by the density matrix 0.5 * g * g.dag() + 0.5 * e * e.dag(), which is a statistical mixture of the ground state g and the excited state e with equal probabilities. 

# Calculate the inner product between the initial ground and excited states
initial_inner_product = g.overlap(e)
P_11 =result.expect[0]
P_00 = 1-result.expect[0]
# Calculate the inner product between the evolved ground and excited states at each time step
evolved_inner_products = [state.eigenstates()[1][0].overlap(state.eigenstates()[1][1]) for state in result.states]

# %%
# Print initial and final values
print("\nInitial values:")
print(f"Entropy: {entropies[0]:.4f}")
print(f"Purity: {purity[0]:.4f}")
print(f"Trace: {trace[0]:.4f}")
print(f"Inner Product: {initial_inner_product:.4f}")

print("\nFinal values:")
print(f"Entropy: {entropies[-1]:.4f}")
print(f"Purity: {purity[-1]:.4f}")
print(f"Trace: {trace[-1]:.4f}")
print(f"Inner Product: {evolved_inner_products[-1]:.4f}")

print(f"Maximum Entropy: {entropy_max:.4f}")
# Out:
# Initial values:
# Entropy: 0.0000
# Purity: 1.0000
# Trace: 1.0000
# Inner Product: 0.0000+0.0000j
#
# Final values:
# Entropy: 0.0007
# Purity: 0.9999
# Trace: 1.0000
# Inner Product: 0.0000+0.0000j
# Maximum Entropy: 1.0000

# %% [markdown]
# <font face="Arial" size="4" color="black">
#
# The initial **inner product** between the ground state **g** and the excited state **e** is 0 + 0j, which means they are **orthogonal states**, as expected. The final **inner product** between the evolved ground state and the evolved excited state is also 0 + 0j, indicating that the inner product remains unchanged throughout the evolution. The fact that the inner product between the evolved states remains constant and equal to the initial inner product (0 in this case) confirms that the evolution is **isometric**. An isometric evolution preserves the inner product between states, which is exactly what you observe in your results.
#
# Additionally, the **trace** of the **density matrices** remains **constant** at 1 throughout the evolution, further supporting the isometric nature of the evolution.
#
# In **quantum mechanics**, the **orthogonality** of states is a fundamental property of the **Hilbert space**, which is the mathematical framework used to describe quantum systems. In a **Hilbert space**, two states are orthogonal if their inner product is zero. Orthogonality is a key concept in quantum mechanics because it allows us to distinguish between different quantum states.
#
# In the case of a two-level system, like the one we are simulating, the ground state and the excited state are typically chosen to be orthogonal. This orthogonality ensures that the states are distinct and can be uniquely identified. It also allows for the superposition principle, where any quantum state of the system can be expressed as a linear combination of the orthogonal basis states.
#
# Regarding **black hole evaporation**, the situation is more complex. In the context of the information paradox and the **Page curve**, the orthogonality of states is not a strict requirement. The focus is on the **entanglement** between the black hole and the emitted radiation, and how the information is encoded in this entanglement. In the case of black hole evaporation, the Hilbert space is divided into two parts: one for the black hole and one for the emitted radiation. The orthogonality of states within each subspace is still important, but the main concern is the entanglement between the two subspaces and how it evolves over time.
#
# The **Page curve** describes the entropy of the emitted radiation, which is related to the entanglement between the black hole and the radiation. The curve shows that the entropy initially increases, reaches a maximum, and then decreases, indicating that information is not lost but rather encoded in the entanglement.
#
# The system undergoes **non-unitary isometric evolution**. The increase in **entropy**, decrease in **purity**, and constant **trace** suggest that the system loses information to the environment while preserving the trace, consistent with non-unitary isometric evolution. The system and its environment, when considered together, could exhibit a **Page curve**-like behavior. In this case, the total entropy of the system plus environment would follow the Page curve, while the system alone would show non-unitary isometric evolution. This would mean that information is conserved in the combined system but appears to be lost when considering only the subsystem of interest.
#
# Let's plot the results
# </font>

# %%
# Plot the von Neumann entropy over time
plt.plot(tlist, entropies, color='blue', label=r'von Neumann Entropy')
plt.xlabel("Time")
plt.ylabel("von Neumann Entropy")
plt.title("von Neumann Entropy vs Time")
plt.legend()

# Plot the purity
plt.plot(tlist, purity, color='green', label=r'Purity')
plt.axhline(1.0, color='green', linestyle='--', label=r'Pure state')
plt.xlabel("Time")
plt.ylabel("Purity")
#plt.title("Purity Dynamics")
plt.legend()

# Plot the trace
plt.plot(tlist, trace, color='black', label=r'Trace')
plt.axhline(1.0, color='black', linestyle='--', label=r'Ideal trace')
plt.xlabel("Time")
plt.ylabel("Trace of Density Matrix")
#plt.title("Trace Dynamics")
plt.legend()
plt.savefig('two-level system incoherent damping dephasing von Neumann Purity.png', dpi=300)  # Save the plot as a PNG image
plt.show()
